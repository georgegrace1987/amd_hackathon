# %%
DB_PATH       = "complaints.duckdb"
import duckdb

def get_conn():
    return duckdb.connect(DB_PATH)

# %%
with get_conn() as conn:
    conn.execute("""DROP TABLE IF EXISTS user_authentication""")
print("user_authentication dropped if it existed.")
